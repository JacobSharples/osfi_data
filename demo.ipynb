# %%
from crawler import OSFICrawler

# %%
osfi = OSFICrawler()

# %%
osfi.get_available_banks()
# Out:
# {'Z005': 'Total All Banks',
#  'Z001': 'Total Domestic Banks',
#  'AV': 'ADS Canadian Bank (Inactive Dec 21, 2022)',
#  'FG': 'Amicus Bank (Inactive Nov 01, 2006)',
#  'AI': 'B.C. Bancorp (Inactive Jan 12, 1996)',
#  'FQ': 'B2B Bank',
#  'AC': 'Bank of Montreal',
#  'AE': 'The Bank of Nova Scotia',
#  'FJ': 'BCPBank Canada (Inactive Dec 15, 2007)',
#  'AW': 'Bridgewater Bank',
#  'FZ': 'Caisse populaire acadienne ltée (UNI)',
#  'AA': 'Canadian Imperial Bank of Commerce',
#  'AR': 'Canadian Tire Bank',
#  'AO': 'Canadian Western Bank',
#  'BG': 'Coast Capital Savings Federal Credit Union',
#  'BD': 'Concentra Bank',
#  'FV': 'Continental Bank of Canada (Inactive Dec 17, 2019)',
#  'AM': 'Continental Bank of Canada (Inactive Oct 23, 1996)',
#  'FE': 'CS Alterna Bank',
#  'AY': 'Digital Commerce Bank',
#  'FS': 'Equitable Bank',
#  'BB': 'Exchange Bank of Canada',
#  'FM': 'Fairstone Bank of Canada',
#  'EW': 'First Nations Bank of Canada',
#  'AU': 'General Bank of Canada',
# ...

# %%
osfi.get_available_dates()
# Out:
# {'4 - 2024': 'April 30, 2024',
#  '3 - 2024': 'March 31, 2024',
#  '2 - 2024': 'February 29, 2024',
#  '1 - 2024': 'January 31, 2024',
#  '12 - 2023': 'December 31, 2023',
#  '11 - 2023': 'November 30, 2023',
#  '10 - 2023': 'October 31, 2023',
#  '9 - 2023': 'September 30, 2023',
#  '8 - 2023': 'August 31, 2023',
#  '7 - 2023': 'July 31, 2023',
#  '6 - 2023': 'June 30, 2023',
#  '5 - 2023': 'May 31, 2023',
#  '4 - 2023': 'April 30, 2023',
#  '3 - 2023': 'March 31, 2023',
#  '2 - 2023': 'February 28, 2023',
#  '1 - 2023': 'January 31, 2023',
#  '12 - 2022': 'December 31, 2022',
#  '11 - 2022': 'November 30, 2022',
#  '10 - 2022': 'October 31, 2022',
#  '9 - 2022': 'September 30, 2022',
#  '8 - 2022': 'August 31, 2022',
#  '7 - 2022': 'July 31, 2022',
#  '6 - 2022': 'June 30, 2022',
#  '5 - 2022': 'May 31, 2022',
#  '4 - 2022': 'April 30, 2022',
#  '3 - 2022': 'March 31, 2022',
#  '2 - 2022': 'February 28, 2022',
#  '1 - 2022': 'January 31, 2022',
#  '12 - 2021': 'December 31, 2021',
# ...

# %%
bs = osfi.get_monthly_balance_sheet('AW', '4 - 2024')

# %%
bs['assets']
# Out:
#                                    Section I - Assets  \
# 0                         1. Cash and cash equivalent
# 1   (a) Gold, bank notes, deposits with Bank of Ca...
# 2   (b) Deposits with regulated financial institut...
# 3                                       2. Securities
# 4   (a) Securities issues or guaranteed by Canada/...
# 5       (i) Treasury Bills and other short term paper
# 6                                (ii)Other securities
# 7   (b) Other securities, less allowance for expec...
# 8                                            (i) Debt
# 9                                         (ii) Shares
# 10                                           3. Loans
# 11  (a) Non-Mortgage Loans, less allowance for exp...
# 12  (i) Call and other short loans to investment d...
# 13           (ii) To regulated financial institutions
# 14  (iii) To Canadian federal government, province...
# 15                        (iv) To foreign governments
# ...

# %%
bs['liabilities and equity']
# Out:
#                              Section II - Liabilities  \
# 0                       1. Demand and notice deposits
# 1                          (a) Federal and Provincial
# 2                (b) Municipal or School Corporations
# 3                     (c) Deposit-taking institutions
# 4                                     (d) Individuals
# 5                                   (i) Tax sheltered
# 6                                          (ii) Other
# 7                                           (e) Other
# 8                              2. Fixed-term deposits
# 9                          (a) Federal and Provincial
# 10               (b) Municipal or School Corporations
# 11                    (c) Deposit-taking institutions
# 12                                    (d) Individuals
# 13                                  (i) Tax-sheltered
# 14                                         (ii) Other
# 15                                         (e) Others
# ...
